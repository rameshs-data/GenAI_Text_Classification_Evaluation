# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# %cd /content/drive/MyDrive/Colab\ Notebooks/GitHub/
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/GitHub
# /content/drive/MyDrive/Colab Notebooks/GitHub

# %%
# MAJOR CHANGES
# Set current working project repo
repository = 'TextClassifier-NLP'

# %%
# Declare git credentials
username = 'rameshs-data'
useremail = "ramesh.s.data@gmail.com"
git_token = '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'

url_template = "https://{username}:{git_token}@github.com/{username}/{repository}"
url = url_template.format(username=username, git_token=git_token, repository=repository)
#print(url)

# %%
# !git config --global user.email {useremail}
# !git config --global user.name {username}
# !git config --global credential.username {username}
# !git config --global credential.helper store
# !git config --global credential.helper cache

# %%
#!git clone https://{git_token}@github.com/{username}/{repository}
#!git clone https://github.com/{username}/{repository}
# %cd {repository}
# %ls -a
# Out:
# /content/drive/MyDrive/Colab Notebooks/TextClassifier-NLP
# best_xgboost_model.pkl  grid_search_object.pkl               train_embs2.npy
# data.csv                README.md                            train_embs.npy
# .git/                   test_embs.npy                        train_models.ipynb
# .gitignore              TextClassifierNLP_gitCommands.ipynb  val_embs2.npy

# %%
# !git init

# %%
# !touch .gitignore
# !git add .gitignore

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	best_xgboost_model.pkl
# 	gitCommands.ipynb
# 	grid_search_object.pkl
# 	test_embs.npy
# 	train_embs.npy
# 	train_embs2.npy
# 	val_embs2.npy
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add train_models.ipynb

# %%
# !git add gitCommands.ipynb

# %%
# !git add Linear_Regression/Automobile\ Price\ Prediction/*
#!git rm README.md
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   gitCommands.ipynb
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	best_xgboost_model.pkl
# 	grid_search_object.pkl
# 	test_embs.npy
# 	train_embs.npy
# 	train_embs2.npy
# 	val_embs2.npy

# %%
# !git rm -rf --cached .ipynb_checkpoints/train_models-checkpoint.ipynb
# Out:
# rm '.ipynb_checkpoints/train_models-checkpoint.ipynb'

# %%
# !git commit -m "Git commands file google collab"
# Out:
# [main 81e10c9] Git commands file google collab
#  1 file changed, 1 insertion(+)
#  create mode 100644 gitCommands.ipynb

# %%
# !git config pull.rebase false
# !git config pull.rebase true
# !git config pull.ff only

# %%
# Fetch the latest changes from the remote repository
# !git fetch

# Merge the remote changes into your local branch
# !git merge origin/main
# OR
# Rebase your local changes on top of the remote changes
# !git rebase origin/main

# Resolve any conflicts if prompted by Git

# %%
# !git merge origin/main
# Out:
# Auto-merging README.md
# CONFLICT (add/add): Merge conflict in README.md
# Automatic merge failed; fix conflicts and then commit the result.

# %%
# !git reset HEAD README.md
# Out:
# Unstaged changes after reset:
# M	README.md

# %%
# !git checkout -- README.md

# %%
# !git rm -f README.md
# Out:
# rm 'README.md'

# %%
# !git rm --cached README.md
# Out:
# fatal: pathspec 'README.md' did not match any files

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 2.39 KiB | 40.00 KiB/s, done.
# From https://github.com/rameshs-data/TextClassifier-NLP
#  * branch            main       -> FETCH_HEAD
#    db44d7d..4b07ae0  main       -> origin/main
# Updating d5817f9..4b07ae0
# Fast-forward
#  README.md | 32 ++++++++++++++++++++++++++++++++
#  1 file changed, 32 insertions(+)
#  create mode 100644 README.md

# %%
# !git push https://{username}:{git_token}@github.com/{username}/{repository} main
#!git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 3.45 KiB | 353.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/rameshs-data/TextClassifier-NLP
#    af5c8e0..81e10c9  main -> main

# %% [markdown]
# For usecase like a chatbox lemmatization is better
